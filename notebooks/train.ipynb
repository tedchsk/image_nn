# %%
import torch
import torch.nn as nn
import torchvision
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import numpy as np
import time
from typing import Type, Any, Callable, Union, List, Optional
from torch import Tensor 
from torchsummary import summary
if torch.cuda.is_available():
    print("Using GPUs")
    device = torch.device("cuda") 
else:
    device = torch.device("cpu")

# %%
torch.manual_seed(43)
batch_size = 128

### for CIFAR 10
# stats = ((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
## for CIFAR 100
stats = ((0.507, 0.487, 0.441), (0.267, 0.256, 0.276))

transform = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(*stats),
    torchvision.transforms.RandomCrop(32, padding=4, padding_mode='constant'),
    torchvision.transforms.RandomHorizontalFlip(p=0.5)
])

train_set = torchvision.datasets.CIFAR100(root="data", train=True, download=True, transform=transform)
train_size = len(train_set)
test_set = torchvision.datasets.CIFAR100(root="data", train=False, download=True, transform=transform)
test_set, validation_set = torch.utils.data.random_split(test_set, [5000, 5000])
test_size = len(test_set)
validation_size = len(validation_set)


train_loader = torch.utils.data.DataLoader(train_set, batch_size, shuffle=True, num_workers=4, pin_memory=True)
test_loader = torch.utils.data.DataLoader(test_set, batch_size, num_workers=4, pin_memory=True)
validation_loader = torch.utils.data.DataLoader(validation_set, batch_size, num_workers=4, pin_memory=True)

data_loaders = {"train": train_loader, "test": test_loader, "validation": validation_loader}
dataset_sizes = {"train": train_size, "test": test_size, "validation": validation_size}
print(dataset_sizes)

# %%
from models import ResNet, DenseNet, DSNet

#### Train Configurations, based on DSNet and ResNet paper
model_n = 3
epochs = 100 ### should be 180
milestones = [int(epochs*0.5), int(epochs*0.75)]
momentum = 0.9
weight_decay = 0.0005
gamma = 0.1
lr = 0.1

model = DSNet(model_n, num_classes=100, device=device)
# model = ResNet(model_n, num_classes=100, device=device)
# model = DenseNet(growth_rate=16, block_config=(2 * model_n, 2 * model_n, 2 * model_n),
#                  num_init_features=16, bn_size=2, num_classes=100)

model.to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=milestones, gamma=gamma)

summary(model, (3, 32, 32))
print('Total Number of Parameters:', sum(p.numel() for p in model.parameters()))

# %%
### Train loop + validation/ also test at the end
print("Configuration: ", "model:DSNet(small)", " model_n:", model_n, " batch size:", batch_size, 
      " optimizer:SGD", " lr:", lr, " epochs:", epochs)

print("----------------------------- Train --------------------------------")
for epoch in range(epochs):
    start_time = time.time()
    print("Epoch {}/{}".format(epoch+1, epochs))
    print("-" * 30)
    
    
    epoch_loss = {"train": 0.0, "validation": 0.0}
    epoch_acc = {"train": 0.0, "validation": 0.0}
    
    running_loss = {"train": 0.0, "validation": 0.0}
    running_corrects = {"train": 0, "validation": 0}
    
    for phase in ["train", "validation"]:
        if phase == "train":
            model.train(True)
        else:
            model.train(False)
        
        for data in data_loaders[phase]:
            inputs, labels = data 
            
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            optimizer.zero_grad() # clear all gradients
            
            outputs = model(inputs) # batch_size x num_classes
            _, preds = torch.max(outputs.data, 1) # values, indices
            loss = loss_fn(outputs, labels)
            
            if phase == "train":
                loss.backward()  # compute gradients
                optimizer.step() # update weights/biases
               
            running_loss[phase] += loss.data.item() * inputs.size(0)
            running_corrects[phase] += torch.sum(preds == labels.data).item()
        
        epoch_loss[phase] = running_loss[phase] / dataset_sizes[phase]
        epoch_acc[phase] =  running_corrects[phase] / dataset_sizes[phase]

    # Visualize the loss and accuracy values.
    print({
        'time': np.round(time.time()-start_time, 5),
        'train_loss': np.round(epoch_loss["train"], 5),
        'train_acc': np.round(epoch_acc["train"], 5),
        'val_loss': np.round(epoch_loss["validation"], 5),
        'val_acc': np.round(epoch_acc["validation"], 5),
    })
    
    scheduler.step()

    
    
### evaluating the model with test set
print("----------------------------- Test --------------------------------")
with torch.no_grad():
    model.eval()
    running_loss = 0
    running_corrects = 0

    for data in test_loader:
        inputs, labels = data 

        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad() # clear all gradients

        outputs = model(inputs) # batch_size x num_classes
        _, preds = torch.max(outputs.data, 1) # values, indices
        loss = loss_fn(outputs, labels)

        running_loss += loss.data.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data).item()

    # Visualize the loss and accuracy values.
    print({
    'time': np.round(time.time()-start_time, 5),
    'test_loss': np.round(running_loss/ dataset_sizes['test'], 5),
    'test_acc': np.round(running_corrects/ dataset_sizes['test'], 5),
    })
# Out:
# Configuration:  model:DSNet(small)  model_n: 3  batch size: 128  optimizer:SGD  lr: 0.1  epochs: 100
# ----------------------------- Train --------------------------------
# Epoch 1/100
# ------------------------------
# {'time': 11.32642, 'train_loss': 3.89058, 'train_acc': 0.0945, 'val_loss': 3.61582, 'val_acc': 0.133}
# Epoch 2/100
# ------------------------------
# {'time': 11.20832, 'train_loss': 3.235, 'train_acc': 0.20014, 'val_loss': 3.18643, 'val_acc': 0.2176}
# Epoch 3/100
# ------------------------------
# {'time': 10.97142, 'train_loss': 2.83238, 'train_acc': 0.27616, 'val_loss': 2.91107, 'val_acc': 0.2578}
# Epoch 4/100
# ------------------------------
# {'time': 11.09191, 'train_loss': 2.53902, 'train_acc': 0.33254, 'val_loss': 2.4892, 'val_acc': 0.3456}
# Epoch 5/100
# ------------------------------
# {'time': 11.14418, 'train_loss': 2.33153, 'train_acc': 0.3804, 'val_loss': 2.6593, 'val_acc': 0.3234}
# Epoch 6/100
# ------------------------------
# {'time': 11.02948, 'train_loss': 2.16312, 'train_acc': 0.41756, 'val_loss': 2.37223, 'val_acc': 0.3858}
# Epoch 7/100
# ------------------------------
# {'time': 10.68075, 'train_loss': 2.03416, 'train_acc': 0.44554, 'val_loss': 2.25172, 'val_acc': 0.409}
# Epoch 8/100
# ------------------------------
# {'time': 10.7531, 'train_loss': 1.93137, 'train_acc': 0.46762, 'val_loss': 2.15697, 'val_acc': 0.4256}
# Epoch 9/100
# ------------------------------
# {'time': 11.33064, 'train_loss': 1.82781, 'train_acc': 0.49454, 'val_loss': 2.06782, 'val_acc': 0.435}
# Epoch 10/100
# ------------------------------
# {'time': 11.52116, 'train_loss': 1.7564, 'train_acc': 0.5112, 'val_loss': 2.13406, 'val_acc': 0.4338}
# Epoch 11/100
# ------------------------------
# {'time': 10.49774, 'train_loss': 1.68684, 'train_acc': 0.5289, 'val_loss': 1.94859, 'val_acc': 0.4674}
# Epoch 12/100
# ------------------------------
# {'time': 10.63394, 'train_loss': 1.62365, 'train_acc': 0.54258, 'val_loss': 1.7797, 'val_acc': 0.5108}
# Epoch 13/100
# ------------------------------
# {'time': 10.54897, 'train_loss': 1.57401, 'train_acc': 0.5565, 'val_loss': 1.92301, 'val_acc': 0.4854}
# Epoch 14/100
# ------------------------------
# {'time': 10.86693, 'train_loss': 1.52419, 'train_acc': 0.56668, 'val_loss': 1.8427, 'val_acc': 0.508}
# Epoch 15/100
# ------------------------------
# {'time': 11.19807, 'train_loss': 1.4797, 'train_acc': 0.57986, 'val_loss': 1.83275, 'val_acc': 0.5112}
# Epoch 16/100
# ------------------------------
# {'time': 11.18614, 'train_loss': 1.43647, 'train_acc': 0.58914, 'val_loss': 1.69912, 'val_acc': 0.5354}
# Epoch 17/100
# ------------------------------
# {'time': 11.23427, 'train_loss': 1.41234, 'train_acc': 0.59688, 'val_loss': 1.81892, 'val_acc': 0.5174}
# Epoch 18/100
# ------------------------------
# {'time': 11.14444, 'train_loss': 1.37834, 'train_acc': 0.60352, 'val_loss': 1.65682, 'val_acc': 0.554}
# Epoch 19/100
# ------------------------------
# {'time': 9.99359, 'train_loss': 1.34659, 'train_acc': 0.61264, 'val_loss': 1.7308, 'val_acc': 0.5294}
# Epoch 20/100
# ------------------------------
# {'time': 11.22162, 'train_loss': 1.31697, 'train_acc': 0.62088, 'val_loss': 1.72052, 'val_acc': 0.5356}
# Epoch 21/100
# ------------------------------
# {'time': 11.06395, 'train_loss': 1.30074, 'train_acc': 0.62384, 'val_loss': 1.59288, 'val_acc': 0.5684}
# Epoch 22/100
# ------------------------------
# {'time': 11.28219, 'train_loss': 1.26186, 'train_acc': 0.63256, 'val_loss': 1.57878, 'val_acc': 0.5628}
# Epoch 23/100
# ------------------------------
# {'time': 11.32669, 'train_loss': 1.24009, 'train_acc': 0.63998, 'val_loss': 1.71403, 'val_acc': 0.5474}
# Epoch 24/100
# ------------------------------
# {'time': 10.91919, 'train_loss': 1.2211, 'train_acc': 0.64308, 'val_loss': 1.7154, 'val_acc': 0.5504}
# Epoch 25/100
# ------------------------------
# {'time': 10.82186, 'train_loss': 1.19813, 'train_acc': 0.65038, 'val_loss': 1.59984, 'val_acc': 0.5662}
# Epoch 26/100
# ------------------------------
# {'time': 10.28084, 'train_loss': 1.18141, 'train_acc': 0.65286, 'val_loss': 1.69553, 'val_acc': 0.5508}
# Epoch 27/100
# ------------------------------
# {'time': 11.09567, 'train_loss': 1.16169, 'train_acc': 0.65898, 'val_loss': 1.59627, 'val_acc': 0.5696}
# Epoch 28/100
# ------------------------------
# {'time': 10.22828, 'train_loss': 1.14252, 'train_acc': 0.6631, 'val_loss': 1.61863, 'val_acc': 0.5646}
# Epoch 29/100
# ------------------------------
# {'time': 14.21314, 'train_loss': 1.12081, 'train_acc': 0.67142, 'val_loss': 1.56638, 'val_acc': 0.5704}
# Epoch 30/100
# ------------------------------
# {'time': 11.50595, 'train_loss': 1.11134, 'train_acc': 0.67428, 'val_loss': 1.62658, 'val_acc': 0.5712}
# Epoch 31/100
# ------------------------------
# {'time': 11.28575, 'train_loss': 1.09418, 'train_acc': 0.676, 'val_loss': 1.59555, 'val_acc': 0.566}
# Epoch 32/100
# ------------------------------
# {'time': 10.51585, 'train_loss': 1.08046, 'train_acc': 0.67924, 'val_loss': 1.54386, 'val_acc': 0.5774}
# Epoch 33/100
# ------------------------------
# {'time': 10.74737, 'train_loss': 1.06376, 'train_acc': 0.68228, 'val_loss': 1.56509, 'val_acc': 0.5762}
# Epoch 34/100
# ------------------------------
# {'time': 11.42681, 'train_loss': 1.04868, 'train_acc': 0.6897, 'val_loss': 1.5486, 'val_acc': 0.58}
# Epoch 35/100
# ------------------------------
# {'time': 11.2828, 'train_loss': 1.04022, 'train_acc': 0.69004, 'val_loss': 1.52403, 'val_acc': 0.5898}
# Epoch 36/100
# ------------------------------
# {'time': 11.38437, 'train_loss': 1.02241, 'train_acc': 0.6959, 'val_loss': 1.5428, 'val_acc': 0.5856}
# Epoch 37/100
# ------------------------------
# {'time': 11.27483, 'train_loss': 1.01228, 'train_acc': 0.69858, 'val_loss': 1.5839, 'val_acc': 0.5868}
# Epoch 38/100
# ------------------------------
# {'time': 11.09282, 'train_loss': 1.00046, 'train_acc': 0.70116, 'val_loss': 1.63613, 'val_acc': 0.5758}
# Epoch 39/100
# ------------------------------
# {'time': 10.41074, 'train_loss': 0.98025, 'train_acc': 0.70528, 'val_loss': 1.51962, 'val_acc': 0.5948}
# Epoch 40/100
# ------------------------------
# {'time': 11.02305, 'train_loss': 0.96838, 'train_acc': 0.70774, 'val_loss': 1.61811, 'val_acc': 0.5808}
# Epoch 41/100
# ------------------------------
# {'time': 10.70601, 'train_loss': 0.95896, 'train_acc': 0.71026, 'val_loss': 1.52897, 'val_acc': 0.596}
# Epoch 42/100
# ------------------------------
# {'time': 10.52101, 'train_loss': 0.95255, 'train_acc': 0.71356, 'val_loss': 1.60107, 'val_acc': 0.5854}
# Epoch 43/100
# ------------------------------
# {'time': 10.29261, 'train_loss': 0.93692, 'train_acc': 0.71892, 'val_loss': 1.54755, 'val_acc': 0.594}
# Epoch 44/100
# ------------------------------
# {'time': 11.10877, 'train_loss': 0.93769, 'train_acc': 0.71578, 'val_loss': 1.56975, 'val_acc': 0.5852}
# Epoch 45/100
# ------------------------------
# {'time': 10.47739, 'train_loss': 0.91804, 'train_acc': 0.72172, 'val_loss': 1.64393, 'val_acc': 0.5738}
# Epoch 46/100
# ------------------------------
# {'time': 10.80885, 'train_loss': 0.91098, 'train_acc': 0.72406, 'val_loss': 1.52939, 'val_acc': 0.5968}
# Epoch 47/100
# ------------------------------
# {'time': 11.30853, 'train_loss': 0.89337, 'train_acc': 0.72878, 'val_loss': 1.63946, 'val_acc': 0.5796}
# Epoch 48/100
# ------------------------------
# {'time': 10.91353, 'train_loss': 0.89096, 'train_acc': 0.72872, 'val_loss': 1.54961, 'val_acc': 0.5948}
# Epoch 49/100
# ------------------------------
# {'time': 10.53863, 'train_loss': 0.88173, 'train_acc': 0.73304, 'val_loss': 1.57212, 'val_acc': 0.588}
# Epoch 50/100
# ------------------------------
# {'time': 10.90263, 'train_loss': 0.87504, 'train_acc': 0.73424, 'val_loss': 1.52441, 'val_acc': 0.605}
# Epoch 51/100
# ------------------------------
# {'time': 10.63272, 'train_loss': 0.86237, 'train_acc': 0.73774, 'val_loss': 1.495, 'val_acc': 0.6016}
# Epoch 52/100
# ------------------------------
# {'time': 10.42375, 'train_loss': 0.86031, 'train_acc': 0.73718, 'val_loss': 1.58478, 'val_acc': 0.6006}
# Epoch 53/100
# ------------------------------
# {'time': 10.65885, 'train_loss': 0.84942, 'train_acc': 0.74102, 'val_loss': 1.594, 'val_acc': 0.5976}
# Epoch 54/100
# ------------------------------
# {'time': 10.8015, 'train_loss': 0.83783, 'train_acc': 0.74294, 'val_loss': 1.54297, 'val_acc': 0.6058}
# Epoch 55/100
# ------------------------------
# {'time': 10.37434, 'train_loss': 0.83411, 'train_acc': 0.74436, 'val_loss': 1.59954, 'val_acc': 0.5852}
# Epoch 56/100
# ------------------------------
# {'time': 10.41584, 'train_loss': 0.82713, 'train_acc': 0.74666, 'val_loss': 1.61879, 'val_acc': 0.5844}
# Epoch 57/100
# ------------------------------
# {'time': 11.00377, 'train_loss': 0.82289, 'train_acc': 0.74832, 'val_loss': 1.53706, 'val_acc': 0.5928}
# Epoch 58/100
# ------------------------------
# {'time': 14.88287, 'train_loss': 0.80805, 'train_acc': 0.75368, 'val_loss': 1.54498, 'val_acc': 0.597}
# Epoch 59/100
# ------------------------------
# {'time': 10.92331, 'train_loss': 0.80554, 'train_acc': 0.75294, 'val_loss': 1.52728, 'val_acc': 0.6054}
# Epoch 60/100
# ------------------------------
# {'time': 11.10722, 'train_loss': 0.79652, 'train_acc': 0.75496, 'val_loss': 1.52894, 'val_acc': 0.6074}
# Epoch 61/100
# ------------------------------
# {'time': 10.60187, 'train_loss': 0.78485, 'train_acc': 0.7585, 'val_loss': 1.57973, 'val_acc': 0.592}
# Epoch 62/100
# ------------------------------
# {'time': 10.82366, 'train_loss': 0.77702, 'train_acc': 0.75928, 'val_loss': 1.57175, 'val_acc': 0.5996}
# Epoch 63/100
# ------------------------------
# {'time': 11.24615, 'train_loss': 0.77406, 'train_acc': 0.76272, 'val_loss': 1.61921, 'val_acc': 0.585}
# Epoch 64/100
# ------------------------------
# {'time': 10.25106, 'train_loss': 0.76321, 'train_acc': 0.76138, 'val_loss': 1.56898, 'val_acc': 0.6006}
# Epoch 65/100
# ------------------------------
# {'time': 10.83402, 'train_loss': 0.76027, 'train_acc': 0.76406, 'val_loss': 1.65145, 'val_acc': 0.5946}
# Epoch 66/100
# ------------------------------
# {'time': 10.96255, 'train_loss': 0.75486, 'train_acc': 0.76592, 'val_loss': 1.64159, 'val_acc': 0.5906}
# Epoch 67/100
# ------------------------------
# {'time': 10.72835, 'train_loss': 0.75211, 'train_acc': 0.76732, 'val_loss': 1.60947, 'val_acc': 0.599}
# Epoch 68/100
# ------------------------------
# {'time': 10.63566, 'train_loss': 0.74961, 'train_acc': 0.767, 'val_loss': 1.57401, 'val_acc': 0.6014}
# Epoch 69/100
# ------------------------------
# {'time': 11.32893, 'train_loss': 0.73695, 'train_acc': 0.76964, 'val_loss': 1.66097, 'val_acc': 0.5956}
# Epoch 70/100
# ------------------------------
# {'time': 10.47271, 'train_loss': 0.72965, 'train_acc': 0.7735, 'val_loss': 1.58079, 'val_acc': 0.6124}
# Epoch 71/100
# ------------------------------
# {'time': 10.63797, 'train_loss': 0.72273, 'train_acc': 0.77284, 'val_loss': 1.62777, 'val_acc': 0.5944}
# Epoch 72/100
# ------------------------------
# {'time': 11.00724, 'train_loss': 0.72814, 'train_acc': 0.77354, 'val_loss': 1.63787, 'val_acc': 0.5948}
# Epoch 73/100
# ------------------------------
# {'time': 11.34114, 'train_loss': 0.71526, 'train_acc': 0.7755, 'val_loss': 1.70067, 'val_acc': 0.5882}
# Epoch 74/100
# ------------------------------
# {'time': 11.25282, 'train_loss': 0.71803, 'train_acc': 0.77364, 'val_loss': 1.65438, 'val_acc': 0.5994}
# Epoch 75/100
# ------------------------------
# {'time': 11.18614, 'train_loss': 0.70278, 'train_acc': 0.78094, 'val_loss': 1.61849, 'val_acc': 0.6048}
# Epoch 76/100
# ------------------------------
# {'time': 11.09384, 'train_loss': 0.70067, 'train_acc': 0.7804, 'val_loss': 1.66181, 'val_acc': 0.598}
# Epoch 77/100
# ------------------------------
# {'time': 10.41323, 'train_loss': 0.69739, 'train_acc': 0.78126, 'val_loss': 1.69613, 'val_acc': 0.589}
# Epoch 78/100
# ------------------------------
# {'time': 11.34864, 'train_loss': 0.68388, 'train_acc': 0.78302, 'val_loss': 1.66658, 'val_acc': 0.6038}
# Epoch 79/100
# ------------------------------
# {'time': 10.60643, 'train_loss': 0.68705, 'train_acc': 0.7839, 'val_loss': 1.62975, 'val_acc': 0.6008}
# Epoch 80/100
# ------------------------------
# {'time': 10.57981, 'train_loss': 0.67705, 'train_acc': 0.7885, 'val_loss': 1.60252, 'val_acc': 0.6024}
# Epoch 81/100
# ------------------------------
# {'time': 11.31383, 'train_loss': 0.67419, 'train_acc': 0.78746, 'val_loss': 1.64493, 'val_acc': 0.593}
# Epoch 82/100
# ------------------------------
# {'time': 10.49041, 'train_loss': 0.66881, 'train_acc': 0.78928, 'val_loss': 1.64602, 'val_acc': 0.5996}
# Epoch 83/100
# ------------------------------
# {'time': 10.77928, 'train_loss': 0.66242, 'train_acc': 0.79202, 'val_loss': 1.62056, 'val_acc': 0.6014}
# Epoch 84/100
# ------------------------------
# {'time': 10.74779, 'train_loss': 0.66434, 'train_acc': 0.79022, 'val_loss': 1.73474, 'val_acc': 0.5836}
# Epoch 85/100
# ------------------------------
# {'time': 10.88946, 'train_loss': 0.65854, 'train_acc': 0.7924, 'val_loss': 1.66447, 'val_acc': 0.6024}
# Epoch 86/100
# ------------------------------
# {'time': 19.26123, 'train_loss': 0.65264, 'train_acc': 0.79562, 'val_loss': 1.64963, 'val_acc': 0.5986}
# Epoch 87/100
# ------------------------------
# {'time': 11.0933, 'train_loss': 0.65484, 'train_acc': 0.79396, 'val_loss': 1.63648, 'val_acc': 0.5972}
# Epoch 88/100
# ------------------------------
# {'time': 11.48028, 'train_loss': 0.65026, 'train_acc': 0.79236, 'val_loss': 1.64538, 'val_acc': 0.5978}
# Epoch 89/100
# ------------------------------
# {'time': 10.85368, 'train_loss': 0.63837, 'train_acc': 0.79704, 'val_loss': 1.70016, 'val_acc': 0.6046}
# Epoch 90/100
# ------------------------------
# {'time': 10.47126, 'train_loss': 0.63578, 'train_acc': 0.79778, 'val_loss': 1.70853, 'val_acc': 0.5922}
# Epoch 91/100
# ------------------------------
# {'time': 10.93964, 'train_loss': 0.50893, 'train_acc': 0.8411, 'val_loss': 1.50335, 'val_acc': 0.6372}
# Epoch 92/100
# ------------------------------
# {'time': 10.94572, 'train_loss': 0.45839, 'train_acc': 0.85676, 'val_loss': 1.52514, 'val_acc': 0.6344}
# Epoch 93/100
# ------------------------------
# {'time': 11.57532, 'train_loss': 0.44897, 'train_acc': 0.85852, 'val_loss': 1.51417, 'val_acc': 0.6302}
# Epoch 94/100
# ------------------------------
# {'time': 11.35527, 'train_loss': 0.43338, 'train_acc': 0.86242, 'val_loss': 1.52513, 'val_acc': 0.642}
# Epoch 95/100
# ------------------------------
# {'time': 11.25902, 'train_loss': 0.42832, 'train_acc': 0.86466, 'val_loss': 1.51925, 'val_acc': 0.6364}
# Epoch 96/100
# ------------------------------
# {'time': 10.6317, 'train_loss': 0.4206, 'train_acc': 0.86654, 'val_loss': 1.52635, 'val_acc': 0.6356}
# Epoch 97/100
# ------------------------------
# {'time': 11.30278, 'train_loss': 0.41373, 'train_acc': 0.86976, 'val_loss': 1.57597, 'val_acc': 0.6288}
# Epoch 98/100
# ------------------------------
# {'time': 11.36364, 'train_loss': 0.42093, 'train_acc': 0.86744, 'val_loss': 1.5645, 'val_acc': 0.6368}
# Epoch 99/100
# ------------------------------
# {'time': 10.51541, 'train_loss': 0.41496, 'train_acc': 0.8683, 'val_loss': 1.55676, 'val_acc': 0.6372}
# Epoch 100/100
# ------------------------------
# {'time': 11.26386, 'train_loss': 0.40668, 'train_acc': 0.8696, 'val_loss': 1.56736, 'val_acc': 0.6412}
# ----------------------------- Test --------------------------------
# {'time': 11.96233, 'test_loss': 1.56516, 'test_acc': 0.6444}
